# %% [markdown]
# # Analysis
# Trying to analyse and visualize the dataset.

# %%
# importing the modules
# !whereis python
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# python: /home/manav/Documents/Semester 6/Mini Project/Parkinsons-Disease-Detection/venv/bin/python

# %%
df = pd.read_csv('parkinsons.csv')
print(f"Columns : {len(df.columns)}")
print(f"Rows : {len(df)}")
# print(df)
# Out:
# Columns : 24
# Rows : 195

# %%
# print(df.dtypes)
df = df.drop(columns=['name','status'])
print(df.dtypes)
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()
