# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# loading the data from csv file to a Pandas DataFrame
df = pd.read_csv('parkinsons.csv')
# printing the first 5 rows of the dataframe
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# From here on we will be trying to do dataset cleaning and **transformations**.
# Since the data is not having null values, we will proceed with **feature selection** and **dimensionality reduction**.

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\manav\AppData\Local\Temp\ipykernel_7804\402830966.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
# print(df.columns)
col = [x for x in df.columns]
# print(col[5:9])
dropped_cols = df.drop(columns=col[5:9])
print(dropped_cols.columns)
col = [x for x in dropped_cols.columns]
# print(col[6:11])
dropped_cols = dropped_cols.drop(columns=col[6:11])
# Out:
# Index(['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dropped_cols.corr(),annot=True)
plt.show()
# Out:
# C:\Users\manav\AppData\Local\Temp\ipykernel_7804\2485723045.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dropped_cols.corr(),annot=True)

# %%
dropped_cols = dropped_cols.drop(columns=["NHR","MDVP:Shimmer"])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dropped_cols.corr(),annot=True)
plt.show()
# Out:
# C:\Users\manav\AppData\Local\Temp\ipykernel_7804\1832123096.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dropped_cols.corr(),annot=True)

# %%
dropped_cols.to_csv("transformed_data/without_Positive_Correlating_Attributes.csv")
